# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjanaSuresh30/BIS_LAB_1BM22CS239/blob/main/BIS_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Genetic Algorithm Optimization problem
import random

# Define the problem: maximize f(x) = x^2
def fitness_function(x):
    return x ** 2

# Initialize parameters
POPULATION_SIZE = 100
MUTATION_RATE = 0.01
CROSSOVER_RATE = 0.9
NUM_GENERATIONS = 200
X_RANGE = (-10, 10)  # The range for the x values

# Create an individual (a solution)
def create_individual():
    return random.uniform(X_RANGE[0], X_RANGE[1])

# Create the initial population
def create_population():
    return [create_individual() for _ in range(POPULATION_SIZE)]

# Evaluate the fitness of each individual
def evaluate_population(population):
    return [fitness_function(ind) for ind in population]

# Selection using roulette wheel method
def roulette_wheel_selection(population, fitness_values):
    total_fitness = sum(fitness_values)
    pick = random.uniform(0, total_fitness)
    current = 0
    for individual, fitness in zip(population, fitness_values):
        current += fitness
        if current > pick:
            return individual

# Crossover (linear crossover)
def crossover(parent1, parent2):
    if random.random() < CROSSOVER_RATE:
        alpha = random.random()  # Weighted combination
        offspring1 = alpha * parent1 + (1 - alpha) * parent2
        offspring2 = alpha * parent2 + (1 - alpha) * parent1
        return offspring1, offspring2
    else:
        return parent1, parent2


# Mutation
def mutate(individual):
    if random.random() < MUTATION_RATE:
        return random.uniform(X_RANGE[0], X_RANGE[1])
    return individual

# Genetic Algorithm function
def genetic_algorithm():
    # Step 1: Initialize the population
    population = create_population()

    for generation in range(NUM_GENERATIONS):
        # Step 2: Evaluate the fitness
        fitness_values = evaluate_population(population)

        # Track the best solution in this generation
        best_individual = population[fitness_values.index(max(fitness_values))]
        best_fitness = max(fitness_values)

        print(f"Generation {generation + 1}: Best Fitness = {best_fitness}, Best Individual = {best_individual}")

        # Step 3: Create a new population
        new_population = []

        while len(new_population) < POPULATION_SIZE:
            # Step 4: Selection
            parent1 = roulette_wheel_selection(population, fitness_values)
            parent2 = roulette_wheel_selection(population, fitness_values)

            # Step 5: Crossover
            offspring1, offspring2 = crossover(parent1, parent2)

            # Step 6: Mutation
            offspring1 = mutate(offspring1)
            offspring2 = mutate(offspring2)

            new_population.extend([offspring1, offspring2])

        # Step 7: Replacement with the new population
        population = new_population[:POPULATION_SIZE]  # Ensure population size is maintained

    # After all generations, return the best solution found
    fitness_values = evaluate_population(population)
    best_individual = population[fitness_values.index(max(fitness_values))]
    best_fitness = max(fitness_values)
    print(f"\nBest Solution: x = {best_individual}, f(x) = {best_fitness}")


# Run the genetic algorithm
if __name__ == "__main__":
    genetic_algorithm()
# Out:
# Generation 1: Best Fitness = 96.40496899878679, Best Individual = -9.818603210171332
# Generation 2: Best Fitness = 94.67152554705409, Best Individual = -9.729929370095864
# Generation 3: Best Fitness = 94.49169393456823, Best Individual = -9.72068382031677
# Generation 4: Best Fitness = 94.25048407322184, Best Individual = -9.708268850481112
# Generation 5: Best Fitness = 97.74476258297678, Best Individual = 9.886595095530957
# Generation 6: Best Fitness = 96.68072038658883, Best Individual = 9.832635475120027
# Generation 7: Best Fitness = 84.3455922639806, Best Individual = -9.183985641538243
# Generation 8: Best Fitness = 83.6771798885536, Best Individual = 9.147523155945198
# Generation 9: Best Fitness = 80.97504207936336, Best Individual = -8.998613342030168
# Generation 10: Best Fitness = 77.74153591724553, Best Individual = -8.817116077110787
# Generation 11: Best Fitness = 76.4793143644187, Best Individual = -8.745245243240392
# Generation 12: Best Fitness = 75.30546051782684, Best Individual = -8.67787188876552
# Generation 13: Best Fitness = 74.72083167467665, Best Individual = -8.644121220498741
# Generation 14: Best Fitness = 74.15504021210353, Best Individual = -8.611332081165116
# Generation 15: Best Fitness = 74.14450685491752, Best Individual = -8.610720460850969
# Generation 16: Best Fitness = 73.84227187554272, Best Individual = -8.593152615631979
# Generation 17: Best Fitness = 73.53418281858322, Best Individual = -8.575207450469243
# Generation 18: Best Fitness = 73.25273290610181, Best Individual = -8.5587810409019
# Generation 19: Best Fitness = 75.24210387524877, Best Individual = -8.674220649444466
# Generation 20: Best Fitness = 75.24210387524877, Best Individual = -8.674220649444466
# Generation 21: Best Fitness = 75.17049306267434, Best Individual = -8.670091871639789
# Generation 22: Best Fitness = 75.0632770793725, Best Individual = -8.663906571482203
# Generation 23: Best Fitness = 72.65876646158455, Best Individual = -8.524011172070608
# Generation 24: Best Fitness = 72.3789188232998, Best Individual = -8.50758008033423
# Generation 25: Best Fitness = 72.25850846816651, Best Individual = -8.500500483393111
# Generation 26: Best Fitness = 72.23752938610383, Best Individual = -8.499266402819941
# Generation 27: Best Fitness = 72.00681741853207, Best Individual = -8.48568308496918
# Generation 28: Best Fitness = 84.12672349675056, Best Individual = -9.172062118016349
# Generation 29: Best Fitness = 71.88475047695827, Best Individual = -8.478487511163667
# Generation 30: Best Fitness = 71.77599133469309, Best Individual = -8.47207125410859
# Generation 31: Best Fitness = 71.76997100737579, Best Individual = -8.471715942321
# Generation 32: Best Fitness = 93.20385639462889, Best Individual = 9.654214436950781
# Generation 33: Best Fitness = 95.58312557162215, Best Individual = 9.776662291990153
# Generation 34: Best Fitness = 71.57003401561809, Best Individual = -8.4599074472253
# Generation 35: Best Fitness = 87.50441547742125, Best Individual = 9.354379481153266
# Generation 36: Best Fitness = 84.51714159880069, Best Individual = 9.193320488202328
# Generation 37: Best Fitness = 79.38225092800016, Best Individual = 8.909671763202063
# Generation 38: Best Fitness = 79.38225092800016, Best Individual = 8.909671763202063
# Generation 39: Best Fitness = 71.46267998376823, Best Individual = -8.453560195785455
# Generation 40: Best Fitness = 71.45989297187718, Best Individual = -8.453395351684268
# Generation 41: Best Fitness = 71.42141204534319, Best Individual = -8.451118981847504
# Generation 42: Best Fitness = 81.15952916310734, Best Individual = -9.00885837179758
# Generation 43: Best Fitness = 76.956509790034, Best Individual = -8.772485952683766
# Generation 44: Best Fitness = 76.956509790034, Best Individual = -8.772485952683766
# Generation 45: Best Fitness = 74.74978585918964, Best Individual = -8.645795848803605
# Generation 46: Best Fitness = 74.61439707428057, Best Individual = -8.637962553419676
# Generation 47: Best Fitness = 71.43110422258117, Best Individual = -8.45169238807123
# Generation 48: Best Fitness = 71.14262704740888, Best Individual = -8.434608885266043
# Generation 49: Best Fitness = 71.10259908811031, Best Individual = -8.432235711133217
# Generation 50: Best Fitness = 70.6812314740018, Best Individual = -8.407213062246122
# Generation 51: Best Fitness = 70.42231199810266, Best Individual = -8.391800283497139
# Generation 52: Best Fitness = 70.35537838104845, Best Individual = -8.387811298607549
# Generation 53: Best Fitness = 70.38258738341722, Best Individual = -8.389433078785313
# Generation 54: Best Fitness = 69.79526467327948, Best Individual = -8.354356029837337
# Generation 55: Best Fitness = 69.69617971783542, Best Individual = -8.348423786430311
# Generation 56: Best Fitness = 69.60482291146693, Best Individual = -8.342950491970267
# Generation 57: Best Fitness = 69.53647399003944, Best Individual = -8.338853277881764
# Generation 58: Best Fitness = 69.48264984106693, Best Individual = -8.335625341932477
# Generation 59: Best Fitness = 69.4073251516257, Best Individual = -8.331105878070792
# Generation 60: Best Fitness = 69.40166718676095, Best Individual = -8.330766302493483
# Generation 61: Best Fitness = 69.28240673199066, Best Individual = -8.32360539261627
# Generation 62: Best Fitness = 69.27832634989127, Best Individual = -8.323360279952519
# Generation 63: Best Fitness = 69.23170255429318, Best Individual = -8.320559028953113
# Generation 64: Best Fitness = 69.1886288951163, Best Individual = -8.317970238893398
# Generation 65: Best Fitness = 69.16403439748677, Best Individual = -8.316491712103534
# Generation 66: Best Fitness = 91.27541097127306, Best Individual = -9.553816565712001
# Generation 67: Best Fitness = 69.11279868535867, Best Individual = -8.313410773284252
# Generation 68: Best Fitness = 69.10687154073499, Best Individual = -8.31305428472201
# Generation 69: Best Fitness = 69.10030502590197, Best Individual = -8.312659323339432
# Generation 70: Best Fitness = 69.08637931333584, Best Individual = -8.311821660342325
# Generation 71: Best Fitness = 93.44700585660297, Best Individual = 9.666799152594564
# Generation 72: Best Fitness = 76.36522599904585, Best Individual = -8.738719929088347
# Generation 73: Best Fitness = 92.2792100728921, Best Individual = -9.606206851452455
# Generation 74: Best Fitness = 86.91113038288618, Best Individual = -9.322613924371543
# Generation 75: Best Fitness = 79.83107317816936, Best Individual = -8.93482362322667
# Generation 76: Best Fitness = 77.66134834610526, Best Individual = -8.812567636398898
# Generation 77: Best Fitness = 77.66134834610526, Best Individual = -8.812567636398898
# Generation 78: Best Fitness = 77.66134834610526, Best Individual = -8.812567636398898
# Generation 79: Best Fitness = 84.02266195082557, Best Individual = -9.166387617312807
# Generation 80: Best Fitness = 78.8688048781159, Best Individual = -8.880811048441235
# Generation 81: Best Fitness = 76.22023642187789, Best Individual = -8.730420174417603
# Generation 82: Best Fitness = 72.6882292062462, Best Individual = -8.525739217583787
# Generation 83: Best Fitness = 72.42033117990792, Best Individual = -8.510013582827463
# Generation 84: Best Fitness = 73.93275831879933, Best Individual = -8.598416035456724
# Generation 85: Best Fitness = 72.81834087102008, Best Individual = -8.533366327014216
# Generation 86: Best Fitness = 70.8841919471345, Best Individual = -8.41927502503241
# Generation 87: Best Fitness = 70.68090839364481, Best Individual = -8.407193847749962
# Generation 88: Best Fitness = 70.44094990665977, Best Individual = -8.392910693356612
# Generation 89: Best Fitness = 70.2984620590926, Best Individual = -8.384417812769865
# Generation 90: Best Fitness = 70.02632887558646, Best Individual = -8.368173568681906
# Generation 91: Best Fitness = 69.90324551824365, Best Individual = -8.360816079680479
# Generation 92: Best Fitness = 69.8576011285716, Best Individual = -8.358085972791354
# Generation 93: Best Fitness = 69.85245164940201, Best Individual = -8.357777913381165
# Generation 94: Best Fitness = 69.80429453187932, Best Individual = -8.354896440523923
# Generation 95: Best Fitness = 69.80429453187932, Best Individual = -8.354896440523923
# Generation 96: Best Fitness = 69.7595126028619, Best Individual = -8.352216029465588
# Generation 97: Best Fitness = 69.75508431975621, Best Individual = -8.351950928960024
# Generation 98: Best Fitness = 69.62666041633892, Best Individual = -8.344259129265996
# Generation 99: Best Fitness = 69.62666041633892, Best Individual = -8.344259129265996
# Generation 100: Best Fitness = 69.59110250955212, Best Individual = -8.342128176284042
# Generation 101: Best Fitness = 69.5789265931105, Best Individual = -8.3413983595744
# Generation 102: Best Fitness = 69.5630961868711, Best Individual = -8.340449399575007
# Generation 103: Best Fitness = 69.54495761709494, Best Individual = -8.33936194304426
# Generation 104: Best Fitness = 69.53899554354905, Best Individual = -8.339004469572435
# Generation 105: Best Fitness = 69.52559997229358, Best Individual = -8.338201243211486
# Generation 106: Best Fitness = 69.52368074308026, Best Individual = -8.338086155892146
# Generation 107: Best Fitness = 81.82980154187814, Best Individual = -9.045982618924167
# Generation 108: Best Fitness = 78.32606286318432, Best Individual = -8.850201289416209
# Generation 109: Best Fitness = 78.03574442112188, Best Individual = -8.833784263899695
# Generation 110: Best Fitness = 77.37658527737511, Best Individual = -8.796396152821627
# Generation 111: Best Fitness = 77.14396024367943, Best Individual = -8.783163453089065
# Generation 112: Best Fitness = 76.96016204077799, Best Individual = -8.772694115309047
# Generation 113: Best Fitness = 74.46912684702065, Best Individual = -8.629549631760666
# Generation 114: Best Fitness = 72.66690827200601, Best Individual = -8.524488739625738
# Generation 115: Best Fitness = 71.82877845870031, Best Individual = -8.47518604271908
# Generation 116: Best Fitness = 70.79512463695876, Best Individual = -8.413983874298712
# Generation 117: Best Fitness = 70.65344572235684, Best Individual = -8.405560405015054
# Generation 118: Best Fitness = 70.28182862967022, Best Individual = -8.383425828959794
# Generation 119: Best Fitness = 70.08184242634604, Best Individual = -8.371489857029395
# Generation 120: Best Fitness = 70.0259860145399, Best Individual = -8.368153082642543
# Generation 121: Best Fitness = 69.97949812641743, Best Individual = -8.365374954323173
# Generation 122: Best Fitness = 69.97949812641743, Best Individual = -8.365374954323173
# Generation 123: Best Fitness = 69.88654064901756, Best Individual = -8.359817022460334
# Generation 124: Best Fitness = 69.85400107129446, Best Individual = -8.357870606278519
# Generation 125: Best Fitness = 69.81928321782645, Best Individual = -8.35579339248084
# Generation 126: Best Fitness = 75.94135865253706, Best Individual = -8.714433926110006
# Generation 127: Best Fitness = 69.6801713848652, Best Individual = 8.347464967573401
# Generation 128: Best Fitness = 69.63929690127773, Best Individual = -8.345016291252985
# Generation 129: Best Fitness = 69.6289100483143, Best Individual = -8.344393929358459
# Generation 130: Best Fitness = 73.6140158307628, Best Individual = 8.579861061273824
# Generation 131: Best Fitness = 73.6140158307628, Best Individual = 8.579861061273824
# Generation 132: Best Fitness = 69.59475846166296, Best Individual = -8.342347299271529
# Generation 133: Best Fitness = 69.59475846166296, Best Individual = -8.342347299271529
# Generation 134: Best Fitness = 69.5592385703539, Best Individual = -8.340218136856727
# Generation 135: Best Fitness = 69.48523721211673, Best Individual = -8.335780540064423
# Generation 136: Best Fitness = 69.38362106563612, Best Individual = -8.329683131166282
# Generation 137: Best Fitness = 69.10668135717572, Best Individual = -8.313042845864306
# Generation 138: Best Fitness = 68.99071408951944, Best Individual = -8.306064897983848
# Generation 139: Best Fitness = 68.97622508277816, Best Individual = -8.305192657776107
# Generation 140: Best Fitness = 68.92131523992292, Best Individual = -8.301886245903573
# Generation 141: Best Fitness = 95.2151113221384, Best Individual = -9.757823083154275
# Generation 142: Best Fitness = 78.74987277390963, Best Individual = -8.874112506268423
# Generation 143: Best Fitness = 75.97492180432886, Best Individual = -8.716359435241806
# Generation 144: Best Fitness = 71.35481819050835, Best Individual = -8.4471781199705
# Generation 145: Best Fitness = 70.96108385284705, Best Individual = -8.423840208173885
# Generation 146: Best Fitness = 70.00814561140785, Best Individual = -8.367087044569804
# Generation 147: Best Fitness = 69.91752252902393, Best Individual = -8.361669840948274
# Generation 148: Best Fitness = 90.17228387348665, Best Individual = -9.495908796607445
# Generation 149: Best Fitness = 88.41761778946648, Best Individual = -9.403064276578485
# Generation 150: Best Fitness = 85.46136560509879, Best Individual = -9.24453165958659
# Generation 151: Best Fitness = 81.8951914150996, Best Individual = -9.04959620177053
# Generation 152: Best Fitness = 98.58919740483316, Best Individual = -9.929209304110431
# Generation 153: Best Fitness = 92.797694407944, Best Individual = -9.633155994166398
# Generation 154: Best Fitness = 87.69929443307305, Best Individual = 9.36479014356825
# Generation 155: Best Fitness = 76.02355995786306, Best Individual = -8.719149038631182
# Generation 156: Best Fitness = 73.55167709493293, Best Individual = -8.576227439552483
# Generation 157: Best Fitness = 72.81592812782286, Best Individual = -8.53322495471805
# Generation 158: Best Fitness = 72.58169799873696, Best Individual = -8.519489303868921
# Generation 159: Best Fitness = 86.3716169857759, Best Individual = 9.293633142413999
# Generation 160: Best Fitness = 68.91314779749464, Best Individual = -8.301394328514617
# Generation 161: Best Fitness = 68.91314779749464, Best Individual = -8.301394328514617
# Generation 162: Best Fitness = 68.7023090304615, Best Individual = -8.288685603306565
# Generation 163: Best Fitness = 68.61424951172695, Best Individual = -8.28337186849214
# Generation 164: Best Fitness = 68.45123932019068, Best Individual = -8.273526413820813
# Generation 165: Best Fitness = 68.31571947864475, Best Individual = -8.265332387668675
# Generation 166: Best Fitness = 68.27560549942491, Best Individual = -8.262905390927873
# Generation 167: Best Fitness = 68.24695766408458, Best Individual = -8.261171688331176
# Generation 168: Best Fitness = 82.70664256963448, Best Individual = 9.094319247180323
# Generation 169: Best Fitness = 83.89244161933337, Best Individual = 9.159281719618267
# Generation 170: Best Fitness = 68.16026754981158, Best Individual = -8.255923179742625
# Generation 171: Best Fitness = 68.11213938393657, Best Individual = -8.25300789918055
# Generation 172: Best Fitness = 75.68673930657133, Best Individual = 8.699812601807658
# Generation 173: Best Fitness = 68.04605297583899, Best Individual = -8.249003150432117
# Generation 174: Best Fitness = 76.0549196639168, Best Individual = 8.720947176993839
# Generation 175: Best Fitness = 67.99616395542004, Best Individual = -8.245978653587459
# Generation 176: Best Fitness = 67.95324878298497, Best Individual = -8.243376054929495
# Generation 177: Best Fitness = 77.81873167977997, Best Individual = -8.821492599315604
# Generation 178: Best Fitness = 75.82270321436964, Best Individual = 8.70762328160616
# Generation 179: Best Fitness = 67.9226453452373, Best Individual = -8.24151960170194
# Generation 180: Best Fitness = 67.87489575056881, Best Individual = -8.238622199771562
# Generation 181: Best Fitness = 67.84046534217725, Best Individual = -8.236532361508528
# Generation 182: Best Fitness = 67.65903109840794, Best Individual = -8.225510993148568
# Generation 183: Best Fitness = 67.63776600842517, Best Individual = -8.22421826123463
# Generation 184: Best Fitness = 67.59614024201608, Best Individual = -8.221687189501683
# Generation 185: Best Fitness = 67.56124393703386, Best Individual = -8.219564704838929
# Generation 186: Best Fitness = 67.56124393703386, Best Individual = -8.219564704838929
# Generation 187: Best Fitness = 67.54608139176847, Best Individual = -8.218642308299374
# Generation 188: Best Fitness = 67.52964879523022, Best Individual = -8.2176425326994
# Generation 189: Best Fitness = 67.43764097836946, Best Individual = -8.212042436469106
# Generation 190: Best Fitness = 67.43314136867797, Best Individual = -8.211768467795348
# Generation 191: Best Fitness = 89.88512060574013, Best Individual = 9.480776371465584
# Generation 192: Best Fitness = 67.25199407659015, Best Individual = -8.200731313522603
# Generation 193: Best Fitness = 67.2393828037949, Best Individual = -8.199962365998694
# Generation 194: Best Fitness = 67.20316531326776, Best Individual = -8.197753674834818
# Generation 195: Best Fitness = 88.30925164003924, Best Individual = -9.397300231451544
# Generation 196: Best Fitness = 87.84197982012844, Best Individual = -9.372405231322878
# Generation 197: Best Fitness = 84.23171009199362, Best Individual = -9.177783506489659
# Generation 198: Best Fitness = 80.73202422317053, Best Individual = -8.985100123157812
# Generation 199: Best Fitness = 80.69229024678037, Best Individual = -8.9828887473229
# Generation 200: Best Fitness = 87.10952854987072, Best Individual = 9.333248552881827
#
# Best Solution: x = 9.892296200633272, f(x) = 97.85752412106346

# %%
#APPLICATION BASED-4,Determine the optimal routes for a fleet of vehicles to deliver goods to a set of locations
import numpy as np
import random

# Problem Setup: Locations of the depot and customer points
num_locations = 10  # Number of customer locations (including depot)
num_vehicles = 3    # Number of vehicles
depot = (0, 0)      # The depot location (starting point)

# Randomly generate customer locations
np.random.seed(42)
locations = [depot] + [(random.randint(1, 100), random.randint(1, 100)) for _ in range(num_locations - 1)]

# Calculate Euclidean distance between two points
def euclidean_distance(a, b):
    return np.sqrt((a[0] - b[0])**2 + (a[1] - b[1])**2)

# Fitness Function: Calculate the total distance for a given solution
def calculate_fitness(solution):
    total_distance = 0
    for route in solution:
        route_distance = 0
        # Calculate distance for this route
        for i in range(len(route) - 1):
            route_distance += euclidean_distance(locations[route[i]], locations[route[i+1]])
        # Return to depot
        route_distance += euclidean_distance(locations[route[-1]], depot)
        total_distance += route_distance
    return total_distance

# Generate initial population: Random solutions
def generate_initial_population(pop_size):
    population = []
    for _ in range(pop_size):
        solution = []
        # Assign customers to vehicles randomly
        customers = list(range(1, num_locations))  # Exclude depot (index 0)
        random.shuffle(customers)

        # Create routes for each vehicle
        for i in range(num_vehicles):
            route = []
            # Assign customers to routes
            for j in range(len(customers)//num_vehicles + 1):
                if customers:
                    route.append(customers.pop())
            solution.append(route)

        population.append(solution)

    return population

# Tournament selection: Select the best individuals based on their fitness
def tournament_selection(population, tournament_size=3):
    selected = random.sample(population, tournament_size)
    selected.sort(key=lambda x: calculate_fitness(x))
    return selected[0]

# Crossover: Perform a crossover between two solutions
def crossover(parent1, parent2):
    child1 = []
    child2 = []

    for i in range(num_vehicles):
        route1 = parent1[i]
        route2 = parent2[i]

        # Select a random crossover point
        point = random.randint(1, min(len(route1), len(route2)) - 1)

        # Crossover
        child1_route = route1[:point] + route2[point:]
        child2_route = route2[:point] + route1[point:]

        child1.append(child1_route)
        child2.append(child2_route)

    return child1, child2

# Mutation: Mutate the solution by swapping customers between vehicles
def mutate(solution, mutation_rate=0.1):
    if random.random() < mutation_rate:
        vehicle1, vehicle2 = random.sample(range(num_vehicles), 2)
        route1, route2 = solution[vehicle1], solution[vehicle2]

        # Select random customers to swap
        if route1 and route2:
            customer1, customer2 = random.choice(route1), random.choice(route2)
            route1.remove(customer1)
            route2.remove(customer2)
            route1.append(customer2)
            route2.append(customer1)

    return solution

# Genetic Algorithm: Main function to run the algorithm
def genetic_algorithm(pop_size=50, generations=100, mutation_rate=0.1):
    population = generate_initial_population(pop_size)

    for generation in range(generations):
        # Selection and Crossover
        new_population = []
        while len(new_population) < pop_size:
            parent1 = tournament_selection(population)
            parent2 = tournament_selection(population)
            child1, child2 = crossover(parent1, parent2)
            new_population.append(mutate(child1, mutation_rate))
            new_population.append(mutate(child2, mutation_rate))

        # Evaluate and replace the population
        population = sorted(new_population, key=lambda x: calculate_fitness(x))

    # Return the best solution
    best_solution = population[0]
    return best_solution

# Run the Genetic Algorithm
best_solution = genetic_algorithm()

# Print the best solution and the corresponding fitness
print("Best Solution (Routes for each vehicle):")
for i, route in enumerate(best_solution):
    print(f"Vehicle {i+1}: {' -> '.join(str(loc) for loc in route)} -> Depot")

print(f"Total distance traveled: {calculate_fitness(best_solution)}")
# Out:
# Best Solution (Routes for each vehicle):
# Vehicle 1: 8 -> 9 -> 9 -> 2 -> Depot
# Vehicle 2: 9 -> 1 -> Depot
# Vehicle 3: 6 -> 6 -> Depot
# Total distance traveled: 264.3226580782862
